# %% [markdown]
# # Visualization with Plotly

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).

# %% [markdown]
# Source:
# based on https://github.com/vharivinay/python-eda-viz/tree/main

# %% [markdown]
# ## Imports and Set-up

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ### Fake Data

# %%
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.369900  0.151473 -1.085469  1.173172
# 1  0.138692  0.199605  0.106362  1.515433
# 2 -0.450235 -1.619448 -1.689263 -0.978445
# 3  0.647755 -0.776082 -0.515443 -0.120808
# 4  1.952428  1.928301  0.765869 -0.183114

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})

# %%
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %% [markdown]
# ## Using iplot()
#
# * scatter
# * bar
# * box
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %% [markdown]
# ## Scatter

# %%
fig = px.scatter(df, x='A', y='B')
fig.show()

# %% [markdown]
# ## Bar Plots

# %%
fig = px.bar(df2, x='Category', y='Values')
fig.show()

# %%
counts = df.count()
fig = px.bar(x=counts.index, y=counts.values, labels={'x': 'Columns', 'y': 'Count'})
fig.show()

# %% [markdown]
# ## Boxplots

# %%
fig = px.box(df)
fig.show()

# %% [markdown]
# ## 3D Surface

# %%
df3 = pd.DataFrame({'x':[1,2,3,4,5],'y':[10,20,30,20,10],'z':[5,4,3,2,1]})

fig = go.Figure(data=[go.Surface(z=df3.values)])
fig.update_layout(scene=dict(zaxis_title='Value'))
fig.show()

# %% [markdown]
# ## Histogram

# %%
fig = px.histogram(df, x='A', nbins=20)
fig.show()

# %% [markdown]
# ## Bubble plot / Scatter Matrix
#
# Similar to sns.pairplot()

# %%
fig = px.scatter(df, x='A', y='B', size=df['C'].abs())
fig.show()

# %% [markdown]
# ## Scatter Matrix
#
# Similar to sns.pairplot()

# %%
fig = px.scatter_matrix(df, dimensions=['A', 'B', 'C'], color='D')
fig.show()
