# %% [markdown]
# # Neural Networks with Keras

# %% [markdown]
# Example notebook for experimenting with:
# * Creating and fitting a simple neural network
# * Use of Keras high-level API
#
# @Ricardo Almeida

# %%
# Additional requirements
# conda install keras tensorflow

# %%
from keras.layers import Dense, Input
from keras.models import Sequential

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.metrics import RocCurveDisplay
from sklearn.preprocessing import StandardScaler

# %%
RANDOM_SEED = 7657

TEST_SIZE=0.20

# %% [markdown]
# ## Dataset

# %% [markdown]
# #### Loading dataset

# %% [markdown]
# California housing dataset

# %%
housing = fetch_california_housing()

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %%
housing.target_names
# Out:
# ['MedHouseVal']

# %%
housing.target
# Out:
# array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894])

# %%
housing.feature_names
# Out:
# ['MedInc',
#  'HouseAge',
#  'AveRooms',
#  'AveBedrms',
#  'Population',
#  'AveOccup',
#  'Latitude',
#  'Longitude']

# %% [markdown]
# #### Feature plotting

# %%
data = pd.DataFrame(data=housing.data, columns=housing.feature_names)
data['target'] = housing.target

# %%
feature = 'AveRooms'
plt.figure(figsize=(10, 6))
sns.scatterplot(x=feature, y='target', data=data)
plt.xlabel(feature)
plt.ylabel('Target')
plt.show()

# %%
feature = 'MedInc'
plt.figure(figsize=(10, 6))
sns.scatterplot(x=feature, y='target', data=data)
plt.xlabel(feature)
plt.ylabel('Target')
plt.show()

# %%
# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(housing.data)

# %%
X_train, X_dev, y_train, y_dev = train_test_split(
    X_scaled, housing.target, random_state=RANDOM_SEED, test_size=TEST_SIZE)

# %% [markdown]
# ## Neural network

# %% [markdown]
# #### Create Keras model

# %% [markdown]
# A fully connected network with three layers:
# - the first layer has 8 neurons and RELU as activation function
# - second hidden layer has 12 neurons and RELU activation function
# - output layer, 1 unit and activation as Linear, because it is a regression problem (we would use Sigmoid for classification)

# %%
model = Sequential()
model.add(Input((8,)))
model.add(Dense(8, activation="relu"))
model.add(Dense(12, activation="relu"))
model.add(Dense(1, activation="linear"))

# %%
model = Sequential([
    Input((8,)),
    Dense(8, activation="relu"),
    Dense(12, activation="relu"),
    Dense(1, activation="linear")
])

# %% [markdown]
# #### Compile the Keras model

# %% [markdown]
# Specifying the **Loss Function**, **Optimizer** and **Metrics** to display

# %%
model.compile(loss="mean_squared_error", optimizer="adam")

# %% [markdown]
# #### Model training

# %% [markdown]
# Epoch: a single pass through all the rows in the training dataset
#
# Batch size: number of samples considered by the model on updating the weights

# %%
history = model.fit(X_train, y_train, validation_data=(X_dev, y_dev), epochs=60, batch_size=32)
# Out:
# Epoch 1/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 420us/step - loss: 2.8759 - val_loss: 0.6967
# Epoch 2/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.6363 - val_loss: 0.5408
# Epoch 3/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.4857 - val_loss: 0.4724
# Epoch 4/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.4270 - val_loss: 0.4472
# Epoch 5/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.4043 - val_loss: 0.4268
# Epoch 6/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 326us/step - loss: 0.3991 - val_loss: 0.4193
# Epoch 7/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3857 - val_loss: 0.4068
# Epoch 8/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3913 - val_loss: 0.4015
# Epoch 9/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.3667 - val_loss: 0.3969
# Epoch 10/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3558 - val_loss: 0.3898
# Epoch 11/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3529 - val_loss: 0.3841
# Epoch 12/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 508us/step - loss: 0.3548 - val_loss: 0.3898
# Epoch 13/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3525 - val_loss: 0.3784
# Epoch 14/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3444 - val_loss: 0.3744
# Epoch 15/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3414 - val_loss: 0.3750
# Epoch 16/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3468 - val_loss: 0.3649
# Epoch 17/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.3386 - val_loss: 0.3651
# Epoch 18/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3403 - val_loss: 0.3726
# Epoch 19/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3385 - val_loss: 0.3596
# Epoch 20/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 338us/step - loss: 0.3342 - val_loss: 0.3571
# Epoch 21/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 366us/step - loss: 0.3341 - val_loss: 0.3551
# Epoch 22/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.3294 - val_loss: 0.3518
# Epoch 23/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3337 - val_loss: 0.3519
# Epoch 24/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3337 - val_loss: 0.3518
# Epoch 25/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 345us/step - loss: 0.3219 - val_loss: 0.3556
# Epoch 26/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 0.3306 - val_loss: 0.3503
# Epoch 27/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3295 - val_loss: 0.3457
# Epoch 28/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3183 - val_loss: 0.3442
# Epoch 29/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3248 - val_loss: 0.3432
# Epoch 30/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3213 - val_loss: 0.3459
# Epoch 31/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3207 - val_loss: 0.3391
# Epoch 32/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 0.3196 - val_loss: 0.3410
# Epoch 33/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3239 - val_loss: 0.3379
# Epoch 34/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.3091 - val_loss: 0.3450
# Epoch 35/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 332us/step - loss: 0.3081 - val_loss: 0.3335
# Epoch 36/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 0.3082 - val_loss: 0.3328
# Epoch 37/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 438us/step - loss: 0.3072 - val_loss: 0.3326
# Epoch 38/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3246 - val_loss: 0.3325
# Epoch 39/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3166 - val_loss: 0.3353
# Epoch 40/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3044 - val_loss: 0.3291
# Epoch 41/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.3103 - val_loss: 0.3306
# Epoch 42/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3166 - val_loss: 0.3318
# Epoch 43/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 331us/step - loss: 0.3064 - val_loss: 0.3261
# Epoch 44/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.3015 - val_loss: 0.3272
# Epoch 45/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 346us/step - loss: 0.3170 - val_loss: 0.3247
# Epoch 46/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.2984 - val_loss: 0.3223
# Epoch 47/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.3034 - val_loss: 0.3236
# Epoch 48/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 340us/step - loss: 0.2976 - val_loss: 0.3223
# Epoch 49/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3059 - val_loss: 0.3214
# Epoch 50/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.3110 - val_loss: 0.3203
# Epoch 51/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 0.2953 - val_loss: 0.3224
# Epoch 52/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 350us/step - loss: 0.3032 - val_loss: 0.3190
# Epoch 53/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 339us/step - loss: 0.3020 - val_loss: 0.3176
# Epoch 54/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 337us/step - loss: 0.2993 - val_loss: 0.3178
# Epoch 55/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 335us/step - loss: 0.3172 - val_loss: 0.3171
# Epoch 56/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.3006 - val_loss: 0.3192
# Epoch 57/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 341us/step - loss: 0.2917 - val_loss: 0.3167
# Epoch 58/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 334us/step - loss: 0.2960 - val_loss: 0.3230
# Epoch 59/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 333us/step - loss: 0.2986 - val_loss: 0.3141
# Epoch 60/60
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 0s 336us/step - loss: 0.2969 - val_loss: 0.3140

# %%
mse_dev = model.evaluate(X_dev, y_dev)
print(f"\n Mean Squared Error (MSE) on Dev dataset: {mse_dev:.2f}")
# Out:
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 0s 255us/step - loss: 0.3211
#
#  Mean Squared Error (MSE) on Dev dataset: 0.31

# %%
pd.DataFrame(history.history).plot(figsize=(8, 5))
plt.grid(True)
plt.gca().set_ylim(0, 1) # set the vertical range to [0-1]
plt.show()
